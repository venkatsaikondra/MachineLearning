# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#Creating the data
data={
    'area':[2600,3000,3200,3600,4000],
    'price':[550000,565000,610000,680000,725000]
}

# %%
#creating the dataframe
df=pd.DataFrame(data)
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#Creating a scatterplot
plt.scatter(df.area,df.price,marker='o',color='red',label='area and price scatterplot')
#A line y=mx+c
m,b=np.polyfit(df.area,df.price,1)
plt.plot(df.area,m*df.area+b,color='blue',label='linearRegression line')
plt.xlabel('area')
plt.ylabel('price')
plt.title('Area VS Price')
plt.legend()
plt.show()

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /Users/kpvarma/PycharmProjects/MachineLearning/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
t=135.78767123*3300+180616.43835616432
print(t)
# Out:
# 628715.7534151643

# %%
areas=[1000,1500,2300,3540,4120,4560,5490,3460,4750,2300,9000,8600]
df_q=pd.DataFrame(areas)
p=reg.predict(df_q)
df_q['prices']=p
print(df_q)
# Out:
#        0        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# /Users/kpvarma/PycharmProjects/MachineLearning/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
