# %%
from sklearn import svm,datasets
iris=datasets.load_iris()

# %%
import pandas as pd
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df['flower']=iris.target
df['flower']=df['flower'].apply(lambda x:iris.target_names[x])
df[47:52]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 47                4.6               3.2                1.4               0.2
# 48                5.3               3.7                1.5               0.2
# 49                5.0               3.3                1.4               0.2
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
#
#         flower
# 47      setosa
# 48      setosa
# 49      setosa
# 50  versicolor
# 51  versicolor

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(iris.target,iris.target,test_size=0.3)

# %%
model = svm.SVC(kernel='rbf',C=30,gamma='auto')
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 model = svm.SVC(kernel='rbf',C=30,gamma='auto')
# ----> 2 model.fit(x_train,y_train)
#
# File ~/PycharmProjects/MachineLearning/.venv/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/PycharmProjects/MachineLearning/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:197, in BaseLibSVM.fit(self, X, y, sample_weight)
#     195     check_consistent_length(X, y)
#     196 else:
# --> 197     X, y = validate_data(
#     198         self,
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(svm.SVC(kernel='linear',C=10,gamma='auto'),iris.data,iris.target,cv=5)
# Out:
# array([1.        , 1.        , 0.9       , 0.96666667, 1.        ])

# %%
cross_val_score(svm.SVC(kernel='rbf',C=10,gamma='auto'),iris.data,iris.target,cv=5)
# Out:
# array([0.96666667, 1.        , 0.96666667, 0.96666667, 1.        ])

# %%
cross_val_score(svm.SVC(kernel='rbf',C=20,gamma='auto'),iris.data,iris.target,cv=5)
# Out:
# array([0.96666667, 1.        , 0.9       , 0.96666667, 1.        ])

# %%
import numpy as np
kernels=['rbf','linear']
c=[1,10,20]
avg_scores={}
for kval in kernels:
    for cval in c:
        cv_score=cross_val_score(svm.SVC(kernel=kval,C=cval,gamma='auto'),iris.data,iris.target,cv=5)
        avg_scores[kval+'-'+str(cval)]=np.average(cv_score)

avg_scores
# Out:
# {'rbf-1': np.float64(0.9800000000000001),
#  'rbf-10': np.float64(0.9800000000000001),
#  'rbf-20': np.float64(0.9666666666666668),
#  'linear-1': np.float64(0.9800000000000001),
#  'linear-10': np.float64(0.9733333333333334),
#  'linear-20': np.float64(0.9666666666666666)}

# %%
#Grid Search CV
from sklearn.model_selection import GridSearchCV
clf=GridSearchCV(svm.SVC(gamma='auto'),{
    'C':[1,10,20],
     'kernel':['rbf','linear']
},cv=5,return_train_score=False)
clf.fit(iris.data,iris.target)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.000843  , 0.000385  , 0.00037355, 0.00031877, 0.00033517,
#         0.00029573]),
#  'std_fit_time': array([3.59878370e-04, 4.77631384e-05, 1.06788105e-05, 2.18102835e-05,
#         8.15851517e-06, 1.64066633e-05]),
#  'mean_score_time': array([0.00043602, 0.00023017, 0.00023041, 0.00019879, 0.0002079 ,
#         0.00018115]),
#  'std_score_time': array([1.22601445e-04, 2.18579782e-05, 4.34576316e-06, 6.62340373e-06,
#         5.51978917e-06, 7.48254595e-06]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
# ...

# %%
df=pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.000843      0.000360         0.000436        0.000123        1
# 1       0.000385      0.000048         0.000230        0.000022        1
# 2       0.000374      0.000011         0.000230        0.000004       10
# 3       0.000319      0.000022         0.000199        0.000007       10
# 4       0.000335      0.000008         0.000208        0.000006       20
# 5       0.000296      0.000016         0.000181        0.000007       20
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier

# %%
model_parms={
    'svm':{
        'model':svm.SVC(gamma='auto'),
        'params':{

        }
    },
    'random_forest':{

    },
    'logistic_regression':{
        'model':
    }
}
